# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
import os
import copy
import time

# --- CONFIGURATION ---
config = {
    'data_path': r'dataset_split/',
    'num_classes': 29,         # Updated to the 29 foundational classes
    'batch_size': 256,          # Can use a larger batch size for a smaller model
    'img_size': 128,           # Smaller images are fine for a basic CNN and train faster
    'epochs': 30,              # A good number of epochs for a baseline
    'lr': 1e-3,                # Standard learning rate for Adam
    'num_workers': 3,
    'pin_memory': True,
}

# --- 1. DATA PREPARATION ---
def get_data_loaders(data_path, img_size, batch_size, num_workers, pin_memory):
    # Basic augmentations for the training set
    train_transform = transforms.Compose([
        transforms.Resize((img_size, img_size)),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(15),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])
    
    # Just resize and normalize for validation and test sets
    val_test_transform = transforms.Compose([
        transforms.Resize((img_size, img_size)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])
    
    train_dataset = datasets.ImageFolder(root=os.path.join(data_path, 'train'), transform=train_transform)
    val_dataset = datasets.ImageFolder(root=os.path.join(data_path, 'val'), transform=val_test_transform)
    test_dataset = datasets.ImageFolder(root=os.path.join(data_path, 'test'), transform=val_test_transform)
    
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=pin_memory)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=pin_memory)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=pin_memory)
    
    class_names = train_dataset.classes
    print(f"Found {len(class_names)} classes.")
    return train_loader, val_loader, test_loader, class_names

# --- 2. MODEL ARCHITECTURE ---
class BasicCNN(nn.Module):
    def __init__(self, num_classes):
        super(BasicCNN, self).__init__()
        self.features = nn.Sequential(
            # Conv Block 1
            # Input: 3 x 128 x 128
            nn.Conv2d(3, 16, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2), # Output: 16 x 64 x 64

            # Conv Block 2
            nn.Conv2d(16, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2), # Output: 32 x 32 x 32

            # Conv Block 3
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2), # Output: 64 x 16 x 16
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64 * 16 * 16, 512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# --- 3. TRAINING AND VALIDATION LOOPS ---
def train_one_epoch(model, dataloader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    for inputs, labels in tqdm(dataloader, desc="Training"):
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)
    return running_loss / len(dataloader.dataset)

def validate_one_epoch(model, dataloader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct_predictions = 0
    with torch.no_grad():
        for inputs, labels in tqdm(dataloader, desc="Validating"):
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            running_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            correct_predictions += torch.sum(preds == labels.data)
    acc = correct_predictions.double() / len(dataloader.dataset)
    return running_loss / len(dataloader.dataset), acc.item()

# --- 4. MAIN EXECUTION ---
if __name__ == '__main__':
    # Setup
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    # Data
    train_loader, val_loader, test_loader, class_names = get_data_loaders(
        config['data_path'], config['img_size'], config['batch_size'], config['num_workers'], config['pin_memory']
    )

    # Model, Loss, Optimizer
    model = BasicCNN(num_classes=config['num_classes']).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=config['lr'])

    # Training Loop
    best_val_acc = 0.0
    best_model_wts = None
    start_time = time.time()

    for epoch in range(config['epochs']):
        print(f"\n--- Epoch {epoch+1}/{config['epochs']} ---")
        train_loss = train_one_epoch(model, train_loader, criterion, optimizer, device)
        val_loss, val_acc = validate_one_epoch(model, val_loader, criterion, device)
        print(f"Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}")
        
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_model_wts = copy.deepcopy(model.state_dict())
            torch.save(model.state_dict(), 'baseline_cnn_best.pth')
            print("✅ New best model saved!")

    print(f"\n🎉 Training finished in {(time.time() - start_time)/60:.2f} minutes!")

    # --- 5. FINAL EVALUATION ---
    print("\n--- Evaluating on Test Set ---")
    model.load_state_dict(torch.load('baseline_cnn_best.pth'))
    model.eval()

    all_preds, all_labels = [], []
    with torch.no_grad():
        for inputs, labels in tqdm(test_loader, desc="Testing"):
            inputs = inputs.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.numpy())

    # Print results
    final_accuracy = accuracy_score(all_labels, all_preds)
    print(f"\nFinal Test Accuracy: {final_accuracy * 100:.2f}%")
    print("\nClassification Report:")
    print(classification_report(all_labels, all_preds, target_names=class_names, zero_division=0))

    # Plot confusion matrix
    cm = confusion_matrix(all_labels, all_preds)
    plt.figure(figsize=(12, 10))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted'); plt.ylabel('True'); plt.title('Confusion Matrix - Baseline CNN')
    plt.savefig('confusion_matrix_baseline_cnn.png')
    print("\nConfusion matrix saved to confusion_matrix_baseline_cnn.png")
    plt.show()
# Out:
# Using device: cuda
# Found 29 classes.
#
# --- Epoch 1/30 ---
# Training: 100%|██████████| 38/38 [00:21<00:00,  1.77it/s]
# Validating: 100%|██████████| 5/5 [00:11<00:00,  2.37s/it]
# Train Loss: 3.0706 | Val Loss: 2.3886 | Val Acc: 0.2922
# ✅ New best model saved!
#
# --- Epoch 2/30 ---
# Training: 100%|██████████| 38/38 [00:15<00:00,  2.49it/s]
# Validating: 100%|██████████| 5/5 [00:07<00:00,  1.52s/it]
# Train Loss: 2.1230 | Val Loss: 1.4780 | Val Acc: 0.5588
# ✅ New best model saved!
#
# --- Epoch 3/30 ---
# Training: 100%|██████████| 38/38 [00:15<00:00,  2.47it/s]
# Validating: 100%|██████████| 5/5 [00:07<00:00,  1.52s/it]
# Train Loss: 1.4878 | Val Loss: 1.0432 | Val Acc: 0.6704
# ✅ New best model saved!
#
# --- Epoch 4/30 ---
# Training: 100%|██████████| 38/38 [00:20<00:00,  1.88it/s]
# Validating: 100%|██████████| 5/5 [00:10<00:00,  2.02s/it]
# Train Loss: 1.1754 | Val Loss: 0.8193 | Val Acc: 0.7445
# ✅ New best model saved!
#
# --- Epoch 5/30 ---
# Training: 100%|██████████| 38/38 [00:15<00:00,  2.51it/s]
# Validating: 100%|██████████| 5/5 [00:07<00:00,  1.50s/it]
# Train Loss: 0.9452 | Val Loss: 0.7675 | Val Acc: 0.7675
# ✅ New best model saved!
#
# --- Epoch 6/30 ---
# Training: 100%|██████████| 38/38 [00:15<00:00,  2.52it/s]
# Validating: 100%|██████████| 5/5 [00:07<00:00,  1.49s/it]
# Train Loss: 0.8749 | Val Loss: 0.6135 | Val Acc: 0.8152
# ✅ New best model saved!
#
# --- Epoch 7/30 ---
# Training: 100%|██████████| 38/38 [00:17<00:00,  2.17it/s]
# Validating: 100%|██████████| 5/5 [00:13<00:00,  2.72s/it]
# Train Loss: 0.7308 | Val Loss: 0.5525 | Val Acc: 0.8441
# ✅ New best model saved!
#
# --- Epoch 8/30 ---
# Training: 100%|██████████| 38/38 [00:18<00:00,  2.02it/s]
# Validating: 100%|██████████| 5/5 [00:08<00:00,  1.76s/it]
# Train Loss: 0.6822 | Val Loss: 0.4842 | Val Acc: 0.8637
# ✅ New best model saved!
#
# --- Epoch 9/30 ---
# Training: 100%|██████████| 38/38 [00:21<00:00,  1.78it/s]
# Validating: 100%|██████████| 5/5 [00:12<00:00,  2.57s/it]
# Train Loss: 0.5712 | Val Loss: 0.4381 | Val Acc: 0.8807
# ✅ New best model saved!
#
# --- Epoch 10/30 ---
# Training: 100%|██████████| 38/38 [00:17<00:00,  2.21it/s]
# Validating: 100%|██████████| 5/5 [00:13<00:00,  2.61s/it]
# Train Loss: 0.5780 | Val Loss: 0.4501 | Val Acc: 0.8714
#
# --- Epoch 11/30 ---
# Training: 100%|██████████| 38/38 [00:23<00:00,  1.59it/s]
# Validating: 100%|██████████| 5/5 [00:12<00:00,  2.50s/it]
# Train Loss: 0.5164 | Val Loss: 0.3847 | Val Acc: 0.8893
# ✅ New best model saved!
#
# --- Epoch 12/30 ---
# Training: 100%|██████████| 38/38 [00:23<00:00,  1.63it/s]
# Validating: 100%|██████████| 5/5 [00:12<00:00,  2.59s/it]
# Train Loss: 0.4980 | Val Loss: 0.3529 | Val Acc: 0.8986
# ✅ New best model saved!
#
# --- Epoch 13/30 ---
# Training: 100%|██████████| 38/38 [00:23<00:00,  1.61it/s]
# Validating: 100%|██████████| 5/5 [00:13<00:00,  2.60s/it]
# Train Loss: 0.4467 | Val Loss: 0.3460 | Val Acc: 0.9063
# ✅ New best model saved!
#
# --- Epoch 14/30 ---
# Training: 100%|██████████| 38/38 [00:20<00:00,  1.86it/s]
# Validating: 100%|██████████| 5/5 [00:07<00:00,  1.52s/it]
# Train Loss: 0.3892 | Val Loss: 0.3126 | Val Acc: 0.9157
# ✅ New best model saved!
#
# --- Epoch 15/30 ---
# Training: 100%|██████████| 38/38 [00:15<00:00,  2.48it/s]
# Validating: 100%|██████████| 5/5 [00:07<00:00,  1.50s/it]
# Train Loss: 0.3368 | Val Loss: 0.3072 | Val Acc: 0.9123
#
# --- Epoch 16/30 ---
# Training: 100%|██████████| 38/38 [00:15<00:00,  2.53it/s]
# Validating: 100%|██████████| 5/5 [00:07<00:00,  1.49s/it]
# Train Loss: 0.3396 | Val Loss: 0.2915 | Val Acc: 0.9208
# ✅ New best model saved!
#
# --- Epoch 17/30 ---
# Training: 100%|██████████| 38/38 [00:15<00:00,  2.51it/s]
# Validating: 100%|██████████| 5/5 [00:07<00:00,  1.49s/it]
# Train Loss: 0.2879 | Val Loss: 0.2789 | Val Acc: 0.9165
#
# --- Epoch 18/30 ---
# Training: 100%|██████████| 38/38 [00:15<00:00,  2.49it/s]
# Validating: 100%|██████████| 5/5 [00:07<00:00,  1.48s/it]
# Train Loss: 0.3171 | Val Loss: 0.2778 | Val Acc: 0.9191
#
# --- Epoch 19/30 ---
# Training: 100%|██████████| 38/38 [00:14<00:00,  2.54it/s]
# Validating: 100%|██████████| 5/5 [00:07<00:00,  1.50s/it]
# Train Loss: 0.3092 | Val Loss: 0.2611 | Val Acc: 0.9284
# ✅ New best model saved!
#
# --- Epoch 20/30 ---
# Training: 100%|██████████| 38/38 [00:15<00:00,  2.52it/s]
# Validating: 100%|██████████| 5/5 [00:07<00:00,  1.50s/it]
# Train Loss: 0.2471 | Val Loss: 0.2513 | Val Acc: 0.9387
# ✅ New best model saved!
#
# --- Epoch 21/30 ---
# Training: 100%|██████████| 38/38 [00:15<00:00,  2.53it/s]
# Validating: 100%|██████████| 5/5 [00:07<00:00,  1.51s/it]
# Train Loss: 0.2326 | Val Loss: 0.2675 | Val Acc: 0.9370
#
# --- Epoch 22/30 ---
# Training: 100%|██████████| 38/38 [00:20<00:00,  1.89it/s]
# Validating: 100%|██████████| 5/5 [00:09<00:00,  1.81s/it]
# Train Loss: 0.2508 | Val Loss: 0.2458 | Val Acc: 0.9319
#
# --- Epoch 23/30 ---
# Training: 100%|██████████| 38/38 [00:20<00:00,  1.88it/s]
# Validating: 100%|██████████| 5/5 [00:12<00:00,  2.55s/it]
# Train Loss: 0.2138 | Val Loss: 0.2594 | Val Acc: 0.9327
#
# --- Epoch 24/30 ---
# Training: 100%|██████████| 38/38 [00:19<00:00,  1.92it/s]
# Validating: 100%|██████████| 5/5 [00:14<00:00,  2.81s/it]
# Train Loss: 0.2021 | Val Loss: 0.2481 | Val Acc: 0.9336
#
# --- Epoch 25/30 ---
# Training: 100%|██████████| 38/38 [00:16<00:00,  2.37it/s]
# Validating: 100%|██████████| 5/5 [00:07<00:00,  1.50s/it]
# Train Loss: 0.1821 | Val Loss: 0.2501 | Val Acc: 0.9387
#
# --- Epoch 26/30 ---
# Training: 100%|██████████| 38/38 [00:19<00:00,  1.95it/s]
# Validating: 100%|██████████| 5/5 [00:13<00:00,  2.64s/it]
# Train Loss: 0.1870 | Val Loss: 0.2563 | Val Acc: 0.9378
#
# --- Epoch 27/30 ---
# Training: 100%|██████████| 38/38 [00:23<00:00,  1.61it/s]
# Validating: 100%|██████████| 5/5 [00:12<00:00,  2.43s/it]
# Train Loss: 0.1771 | Val Loss: 0.2646 | Val Acc: 0.9412
# ✅ New best model saved!
#
# --- Epoch 28/30 ---
# Training: 100%|██████████| 38/38 [00:22<00:00,  1.68it/s]
# Validating: 100%|██████████| 5/5 [00:12<00:00,  2.45s/it]
# Train Loss: 0.1807 | Val Loss: 0.2537 | Val Acc: 0.9387
#
# --- Epoch 29/30 ---
# Training: 100%|██████████| 38/38 [00:23<00:00,  1.61it/s]
# Validating: 100%|██████████| 5/5 [00:12<00:00,  2.58s/it]
# Train Loss: 0.2039 | Val Loss: 0.2471 | Val Acc: 0.9361
#
# --- Epoch 30/30 ---
# Training: 100%|██████████| 38/38 [00:23<00:00,  1.63it/s]
# Validating: 100%|██████████| 5/5 [00:12<00:00,  2.59s/it]
# Train Loss: 0.1806 | Val Loss: 0.2416 | Val Acc: 0.9404
#
# 🎉 Training finished in 14.49 minutes!
#
# --- Evaluating on Test Set ---
# Testing: 100%|██████████| 5/5 [00:16<00:00,  3.37s/it]
# Final Test Accuracy: 93.89%
#
# Classification Report:
#                   precision    recall  f1-score   support
#
#     Alapadmam(1)       0.94      1.00      0.97        46
#        Aralam(1)       0.93      0.90      0.91        41
# Ardhachandran(1)       1.00      0.83      0.91        30
#  Ardhapathaka(1)       0.79      0.92      0.85        37
#      Bramaram(1)       0.93      0.90      0.92        30
#   Chandrakala(1)       0.97      0.89      0.93        38
#      Chaturam(1)       1.00      0.94      0.97        31
#   Hamsapaksha(1)       0.98      0.94      0.96        48
#     Hamsasyam(1)       0.93      0.98      0.96        56
#      Kangulam(1)       0.98      1.00      0.99        53
#        Kapith(1)       0.93      0.93      0.93        43
#    Katakamukha_1       0.90      0.92      0.91        39
#    Katakamukha_2       0.92      0.97      0.94        35
#    Katakamukha_3       0.90      0.95      0.93        40
#    Katrimukha(1)       0.96      0.96      0.96        45
#        Mayura(1)       0.91      0.89      0.90        35
#   Mrigasirsha(1)       0.96      0.93      0.95        46
#       Mukulam(1)       1.00      0.96      0.98        52
#        Mushti(1)       1.00      0.97      0.99        34
#    Padmakosha(1)       1.00      0.93      0.96        28
#       Pathaka(1)       0.96      0.98      0.97        48
#   Sarpasirsha(1)       0.94      0.96      0.95        50
#   Shukatundam(1)       0.90      0.93      0.91        40
#      Sikharam(1)       0.95      0.97      0.96        37
#   Simhamukham(1)       0.92      0.94      0.93        49
#         Suchi(1)       0.86      0.93      0.89        40
#  Tamarachudam(1)       1.00      0.96      0.98        45
#    Tripathaka(1)       0.83      0.77      0.80        44
#     Trishulam(1)       0.98      0.98      0.98        51
#
#         accuracy                           0.94      1211
#        macro avg       0.94      0.94      0.94      1211
#     weighted avg       0.94      0.94      0.94      1211
#
#
# Confusion matrix saved to confusion_matrix_baseline_cnn.png

# %%
# --- 5. FINAL EVALUATION (WITH IMPROVED PLOTTING) ---
print("\n--- Evaluating on Test Set ---")
# Ensure the model is loaded with the best weights and set to evaluation mode
model.load_state_dict(torch.load('baseline_cnn_best.pth'))
model.eval()

all_preds, all_labels = [], []
with torch.no_grad():
    for inputs, labels in tqdm(test_loader, desc="Testing"):
        inputs = inputs.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.numpy())

# --- Print Results ---
final_accuracy = accuracy_score(all_labels, all_preds)
print(f"\nFinal Test Accuracy: {final_accuracy * 100:.2f}%")
print("\nClassification Report:")
print(classification_report(all_labels, all_preds, target_names=class_names, zero_division=0))

# --- Generate Improved Confusion Matrix ---
cm = confusion_matrix(all_labels, all_preds)

# Create a much larger figure to give space for labels
plt.figure(figsize=(20, 18))

# Use Seaborn's heatmap with customizations
sns.heatmap(
    cm, 
    annot=True,          # Show the numbers in the cells
    fmt='d',             # Format as integers
    cmap='Blues',        # Color scheme
    xticklabels=class_names, 
    yticklabels=class_names,
    annot_kws={"size": 12} # Set the font size for the numbers
)

# Rotate labels for better readability
plt.xticks(rotation=90) # Rotate x-axis labels (Predicted)
plt.yticks(rotation=0)  # Keep y-axis labels horizontal (True)

# Add titles and labels
plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)
plt.title('Confusion Matrix - Baseline CNN', fontsize=16)

# Use tight_layout to ensure everything fits without overlapping
plt.tight_layout()

# Save the high-quality figure
plt.savefig('confusion_matrix_baseline_cnn_improved.png', dpi=300) # dpi=300 for high resolution
print("\nImproved confusion matrix saved to confusion_matrix_baseline_cnn_improved.png")
plt.show()
# Out:
# --- Evaluating on Test Set ---
# Testing: 100%|██████████| 5/5 [00:07<00:00,  1.55s/it]
# Final Test Accuracy: 93.89%
#
# Classification Report:
#                   precision    recall  f1-score   support
#
#     Alapadmam(1)       0.94      1.00      0.97        46
#        Aralam(1)       0.93      0.90      0.91        41
# Ardhachandran(1)       1.00      0.83      0.91        30
#  Ardhapathaka(1)       0.79      0.92      0.85        37
#      Bramaram(1)       0.93      0.90      0.92        30
#   Chandrakala(1)       0.97      0.89      0.93        38
#      Chaturam(1)       1.00      0.94      0.97        31
#   Hamsapaksha(1)       0.98      0.94      0.96        48
#     Hamsasyam(1)       0.93      0.98      0.96        56
#      Kangulam(1)       0.98      1.00      0.99        53
#        Kapith(1)       0.93      0.93      0.93        43
#    Katakamukha_1       0.90      0.92      0.91        39
#    Katakamukha_2       0.92      0.97      0.94        35
#    Katakamukha_3       0.90      0.95      0.93        40
#    Katrimukha(1)       0.96      0.96      0.96        45
#        Mayura(1)       0.91      0.89      0.90        35
#   Mrigasirsha(1)       0.96      0.93      0.95        46
#       Mukulam(1)       1.00      0.96      0.98        52
#        Mushti(1)       1.00      0.97      0.99        34
#    Padmakosha(1)       1.00      0.93      0.96        28
#       Pathaka(1)       0.96      0.98      0.97        48
#   Sarpasirsha(1)       0.94      0.96      0.95        50
#   Shukatundam(1)       0.90      0.93      0.91        40
#      Sikharam(1)       0.95      0.97      0.96        37
#   Simhamukham(1)       0.92      0.94      0.93        49
#         Suchi(1)       0.86      0.93      0.89        40
#  Tamarachudam(1)       1.00      0.96      0.98        45
#    Tripathaka(1)       0.83      0.77      0.80        44
#     Trishulam(1)       0.98      0.98      0.98        51
#
#         accuracy                           0.94      1211
#        macro avg       0.94      0.94      0.94      1211
#     weighted avg       0.94      0.94      0.94      1211
#
#
# Improved confusion matrix saved to confusion_matrix_baseline_cnn_improved.png
