# %%
# %pip install split-folders
# Out:
# Collecting split-folders
#   Using cached split_folders-0.5.1-py3-none-any.whl.metadata (6.2 kB)
# Using cached split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import hashlib
from PIL import Image
import shutil

def deduplicate_images(source_dir, clean_dir, duplicates_dir):
    """
    Finds and separates duplicate images from a source directory.

    Args:
        source_dir (str): The folder containing the original dataset (e.g., 'dataset_full').
        clean_dir (str): Where to save the unique images.
        duplicates_dir (str): Where to move the found duplicates.
    """
    if not os.path.exists(clean_dir):
        os.makedirs(clean_dir)
    if not os.path.exists(duplicates_dir):
        os.makedirs(duplicates_dir)

    hashes = {}
    total_files = 0
    duplicate_count = 0

    print(f"Starting de-duplication of '{source_dir}'...")

    # Walk through all subdirectories and files
    for dirpath, _, filenames in os.walk(source_dir):
        # Create corresponding subdirectories in clean and duplicates folders
        structure_clean = os.path.join(clean_dir, os.path.relpath(dirpath, source_dir))
        structure_duplicates = os.path.join(duplicates_dir, os.path.relpath(dirpath, source_dir))
        if not os.path.isdir(structure_clean):
            os.makedirs(structure_clean)
        if not os.path.isdir(structure_duplicates):
            os.makedirs(structure_duplicates)

        for filename in filenames:
            total_files += 1
            path = os.path.join(dirpath, filename)
            try:
                with Image.open(path) as im:
                    im = im.convert("RGB")
                    data = im.tobytes()
                    file_hash = hashlib.md5(data).hexdigest()

                # If we've seen this hash before, it's a duplicate
                if file_hash in hashes:
                    print(f"  DUPLICATE: '{path}' is a copy of '{hashes[file_hash]}'")
                    shutil.move(path, os.path.join(structure_duplicates, filename))
                    duplicate_count += 1
                else:
                    # If it's a new hash, keep it and copy the file
                    hashes[file_hash] = path
                    shutil.copy2(path, os.path.join(structure_clean, filename))

            except Exception as e:
                print(f"Could not process {path}: {e}")

    print("\n--- De-duplication Complete ---")
    print(f"Total files scanned: {total_files}")
    print(f"Unique images found: {len(hashes)}")
    print(f"Duplicates moved: {duplicate_count}")
    print(f"Clean dataset saved to: '{clean_dir}'")

# --- CONFIGURE AND RUN ---
# 1. Your original dataset with all the duplicates
source_dataset_folder = "Bharatanatyam-Mudra-Dataset"

# 2. A new folder where the clean, unique images will be saved
clean_dataset_folder = "dataset_clean"

# 3. A folder to store the duplicates for inspection
duplicates_folder = "dataset_duplicates"

deduplicate_images(source_dataset_folder, clean_dataset_folder, duplicates_folder)
# Out:
# Starting de-duplication of 'Bharatanatyam-Mudra-Dataset'...
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_128.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_11.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_130.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_126.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_142.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_114.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_16.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_154.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_160.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_152.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_166.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_152.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_186.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_152.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_194.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_182.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_219.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_191.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_221.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_146.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_225.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_11.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_231.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_223.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_232.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_20.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_247.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_156.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_249.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_214.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_25.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_111.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_254.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_11.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_262.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_228.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_269.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_126.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_28.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_134.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_290.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_223.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_293.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_156.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_305.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_132.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_307.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_125.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_310.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_222.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_317.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_175.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_320.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_10.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_328.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_111.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_33.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_132.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_332.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_146.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_333.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_23.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_349.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_10.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_350.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_111.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_352.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_11.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_353.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_223.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_361.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_134.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_375.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_132.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_385.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_223.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_387.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_114.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_388.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_126.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_39.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_10.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_402.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_386.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_403.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_196.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_407.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_187.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_408.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_125.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_414.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_132.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_417.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_20.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_427.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_323.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_433.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_386.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_439.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_365.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_441.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_210.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_449.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_44.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_455.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_222.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_456.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_175.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_459.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_132.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_466.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_134.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_47.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_436.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_471.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_156.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_479.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_154.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_482.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_134.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_500.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_243.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_502.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_172.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_504.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_114.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_506.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_4.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_511.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_11.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_512.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_11.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_516.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_125.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_520.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_154.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_521.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_132.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_524.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_386.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_526.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_146.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_527.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_20.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_529.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_517.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_534.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_20.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_59.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_260.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_69.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_175.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_77.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_501.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_79.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_132.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_87.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_329.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_89.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_447.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_9.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_222.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_96.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_126.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_97.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Alapadmam(1)\Alapadmam_11.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_112.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_111.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_114.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_10.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_115.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_0.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_118.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_103.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_120.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_0.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_130.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_0.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_132.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_103.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_137.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_102.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_148.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_138.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_149.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_116.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_152.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_0.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_167.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_153.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_171.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_15.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_173.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_135.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_175.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_10.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_176.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_15.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_184.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_111.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_191.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_153.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_197.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_15.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_198.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_103.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_204.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_151.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_205.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_155.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_21.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_125.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_210.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_153.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_216.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_177.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_218.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_111.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_227.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_11.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_228.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_195.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_230.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_111.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_233.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_169.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_237.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_178.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_238.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_235.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_240.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_15.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_241.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_131.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_242.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_116.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_244.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_113.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_248.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_138.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_249.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_15.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_254.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_102.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_257.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_207.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_259.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_235.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_26.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_232.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_261.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_151.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_264.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_200.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_265.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_232.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_268.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_131.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_269.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_111.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_271.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_169.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_273.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_194.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_275.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_232.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_277.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_15.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_278.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_11.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_279.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_200.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_280.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_153.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_281.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_195.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_283.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_10.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_285.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_116.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_286.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_178.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_287.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_196.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_289.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_111.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_294.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_15.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_295.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_11.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_296.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_122.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_298.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_207.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_30.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_260.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_301.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_109.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_302.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_200.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_306.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_109.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_309.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_177.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_31.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_153.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_311.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_103.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_314.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_247.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_315.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_177.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_316.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_135.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_319.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_11.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_32.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_153.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_320.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_111.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_322.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_11.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_324.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_211.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_329.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_232.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_330.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_135.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_332.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_19.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_333.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_300.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_336.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_109.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_34.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_178.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_340.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_234.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_342.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_138.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_343.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_235.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_345.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_260.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_346.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_1.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_347.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_178.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_348.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_24.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_350.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_102.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_351.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_0.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_355.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_178.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_356.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_11.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_358.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_300.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_359.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_11.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_360.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_178.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_361.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_1.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_362.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_116.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_364.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_138.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_365.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_24.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_366.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_111.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_367.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_263.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_368.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_102.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_377.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_0.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_378.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_153.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_380.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_0.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_386.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_375.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_387.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_178.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_388.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_116.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_389.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_143.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_392.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_177.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_393.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_102.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_394.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_169.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_397.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_153.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_398.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_24.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_40.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_375.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_401.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_391.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_406.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_260.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_410.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_177.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_411.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_247.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_412.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_194.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_413.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_102.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_414.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_384.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_417.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_300.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_418.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_11.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_419.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_200.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_423.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_153.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_426.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_384.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_428.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_194.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_429.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_111.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_430.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_102.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_433.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_177.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_435.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_153.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_439.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_138.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_440.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_384.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_441.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_102.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_443.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_0.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_446.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_177.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_449.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_102.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_45.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_113.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_450.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_11.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_457.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_178.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_460.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_207.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_461.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_178.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_462.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_111.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_477.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_384.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_478.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_195.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_483.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_200.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_487.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_24.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_493.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_195.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_497.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_24.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_5.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_116.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_50.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_151.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_502.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_177.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_504.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_232.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_505.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_116.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_508.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_207.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_51.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_131.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_510.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_384.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_512.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_260.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_513.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_384.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_517.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_143.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_519.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_178.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_521.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_122.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_527.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_260.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_528.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_151.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_532.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_113.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_536.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_10.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_538.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_219.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_539.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_109.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_54.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_475.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_540.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_235.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_545.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_109.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_546.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_151.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_547.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_111.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_548.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_102.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_55.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_260.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_551.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_24.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_553.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_384.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_554.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_151.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_561.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_151.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_562.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_0.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_563.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_178.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_57.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_111.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_573.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_260.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_576.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_263.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_581.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_109.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_585.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_125.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_586.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_196.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_595.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_24.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_597.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_163.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_598.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_113.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_599.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_11.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_602.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_103.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_605.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_11.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_608.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_111.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_609.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_10.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_611.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_138.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_64.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_196.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_74.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_153.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_75.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_177.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_79.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_195.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_8.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_219.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_80.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_10.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_82.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_11.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_83.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_102.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_89.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_138.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_9.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_375.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_92.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_169.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_94.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_109.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_95.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_1.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_98.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_10.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_99.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Aralam(1)\Aralam_11.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_106.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_102.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_124.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_120.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_15.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_134.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_151.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_115.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_153.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_134.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_155.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_120.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_161.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_133.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_163.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_128.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_164.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_137.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_166.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_134.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_168.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_120.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_17.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_120.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_179.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_158.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_18.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_128.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_180.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_158.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_183.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_115.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_185.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_128.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_186.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_109.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_187.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_128.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_188.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_137.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_189.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_110.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_191.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_190.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_193.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_133.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_198.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_158.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_199.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_158.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_20.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_16.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_201.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_133.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_204.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_120.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_205.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_131.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_208.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_157.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_210.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_115.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_211.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_116.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_212.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_113.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_22.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_184.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_227.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_209.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_228.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_215.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_230.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_196.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_232.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_16.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_239.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Ardhachandran(1)\Ardhachandran_157.jpg'
# ...
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_449.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_304.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_450.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_196.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_451.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_375.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_452.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_199.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_456.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_196.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_460.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_163.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_463.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_231.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_467.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_300.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_469.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_188.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_473.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_124.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_474.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_124.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_476.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_375.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_48.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_375.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_482.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_423.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_485.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_265.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_486.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_119.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_493.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_271.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_494.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_167.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_495.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_25.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_5.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_283.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_50.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_189.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_500.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_150.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_504.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_128.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_505.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_196.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_507.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_157.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_508.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_101.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_512.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_193.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_514.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_167.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_518.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_21.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_52.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_160.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_520.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_27.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_522.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_199.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_525.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_124.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_533.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_283.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_545.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_132.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_549.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_203.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_6.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_159.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_61.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_462.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_67.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_150.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_72.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_366.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_77.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_124.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_79.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_188.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_87.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_163.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_88.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_160.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_93.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_132.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_99.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Tripathaka(1)\Tripathaka_128.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_156.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_154.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_184.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_103.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_204.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_131.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_220.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_161.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_226.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_103.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_237.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_20.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_253.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_131.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_254.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_127.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_295.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_2.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_300.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_13.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_321.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_202.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_323.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_114.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_326.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_265.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_335.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_114.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_338.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_208.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_345.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_238.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_349.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_2.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_350.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_33.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_36.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_123.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_375.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_299.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_377.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_127.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_382.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_147.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_388.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_127.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_413.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_368.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_415.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_34.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_437.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_394.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_443.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_161.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_45.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_103.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_451.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_131.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_462.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_14.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_466.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_456.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_471.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_332.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_472.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_2.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_473.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_103.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_475.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_203.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_481.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_103.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_483.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_348.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_487.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_202.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_488.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_147.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_500.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_161.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_504.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_202.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_508.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_243.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_51.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_275.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_524.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_244.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_525.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_347.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_543.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_103.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_546.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_161.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_547.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_274.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_55.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_319.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_554.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_147.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_60.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_114.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_65.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_131.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_70.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_391.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_75.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_327.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_76.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_103.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_81.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_243.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_92.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_243.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_97.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_412.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_98.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Trishulam(1)\Trishulam_147.jpg'
#   DUPLICATE: 'Bharatanatyam-Mudra-Dataset\Varaha(1)\Varaha  _364.jpg' is a copy of 'Bharatanatyam-Mudra-Dataset\Varaha(1)\Varaha  _164.jpg'
#
# --- De-duplication Complete ---
# Total files scanned: 28431
# Unique images found: 24863
# Duplicates moved: 3568
# Clean dataset saved to: 'dataset_clean'

# %%
import splitfolders

# The location of your single, combined dataset
input_folder = "dataset_foundational_29"

# The location where you want the new split dataset
output_folder = "dataset_split"

# This will split the data into 80% training, 10% validation, and 10% testing
# It ensures no files are shared between them.
# The 'stratify' option is not needed as the library does it by default.
splitfolders.ratio(
    input_folder,
    output=output_folder,
    seed=42,  # A fixed seed ensures the split is the same every time you run it
    ratio=(0.8, 0.1, 0.1)  # 80% train, 10% validation, 10% test
)

print("Dataset has been split successfully!")
# Out:
# Copying files: 11861 files [00:05, 2061.51 files/s]
# Dataset has been split successfully!

# %%
import os

def find_overlap(train_dir, test_dir):
    train_files = set()
    for root, _, files in os.walk(train_dir):
        for f in files:
            train_files.add(f)
    test_files = set()
    for root, _, files in os.walk(test_dir):
        for f in files:
            if f in train_files:
                print("Exact filename overlap:", f)
find_overlap("dataset_split/train", "dataset_split/test")

# %%
from PIL import Image
import os
import hashlib

def img_hash(path):
    with Image.open(path) as im:
        im = im.convert("RGB")
        data = im.tobytes()
    return hashlib.md5(data).hexdigest()

def find_pixel_duplicates(train_dir, test_dir):
    train_hashes = {}
    for root, _, files in os.walk(train_dir):
        for f in files:
            p = os.path.join(root, f)
            try:
                h = img_hash(p)
                train_hashes.setdefault(h, []).append(p)
            except Exception:
                pass

    for root, _, files in os.walk(test_dir):
        for f in files:
            p = os.path.join(root, f)
            try:
                h = img_hash(p)
                if h in train_hashes:
                    print("Pixel duplicate found:", p, "matches", train_hashes[h][:3])
            except Exception:
                pass

find_pixel_duplicates("dataset_split/train", "dataset_split/test")

# %%
import os
import shutil

# --- Configuration ---

# 1. The source of your clean, de-duplicated dataset.
#    Make sure this path is correct.
source_dir = "dataset_clean"

# 2. The name of the new folder for your focused dataset.
target_dir = "dataset_foundational_29"

# 3. The list of the 29 foundational classes to copy.
#    These names should match the folder names in your source_dir.
classes_to_copy = [
    'Pathaka(1)', 'Tripathaka(1)', 'Ardhapathaka(1)', 'Katrimukha(1)',
    'Mayura(1)', 'Ardhachandran(1)', 'Aralam(1)', 'Shukatundam(1)',
    'Mushti(1)', 'Sikharam(1)', 'Kapith(1)', 'Katakamukha_1',
    'Katakamukha_2', 'Katakamukha_3', 'Suchi(1)', 'Chandrakala(1)',
    'Padmakosha(1)', 'Sarpasirsha(1)', 'Mrigasirsha(1)', 'Simhamukham(1)',
    'Kangulam(1)', 'Alapadmam(1)', 'Chaturam(1)', 'Bramaram(1)',
    'Hamsasyam(1)', 'Hamsapaksha(1)', 'Mukulam(1)', 'Tamarachudam(1)',
    'Trishulam(1)'
]

# --- Script Logic ---

print(f"Creating new dataset at '{target_dir}'...")

# Create the main target directory if it doesn't exist
if not os.path.exists(target_dir):
    os.makedirs(target_dir)

copied_count = 0
not_found_count = 0

# Loop through the list of classes to copy
for class_name in classes_to_copy:
    source_class_path = os.path.join(source_dir, class_name)
    target_class_path = os.path.join(target_dir, class_name)

    # Check if the class exists in the source directory
    if os.path.exists(source_class_path):
        print(f"  Copying '{class_name}'...")
        # Use shutil.copytree to copy the entire folder
        shutil.copytree(source_class_path, target_class_path)
        copied_count += 1
    else:
        print(f"  WARNING: Class '{class_name}' not found in source directory.")
        not_found_count += 1

print("\n--- Process Complete ---")
print(f"Successfully copied {copied_count} class folders.")
if not_found_count > 0:
    print(f"Skipped {not_found_count} classes that were not found.")
print(f"Your new, focused dataset is ready in the '{target_dir}' folder.")
# Out:
# Creating new dataset at 'dataset_foundational_29'...
#   Copying 'Pathaka(1)'...
#   Copying 'Tripathaka(1)'...
#   Copying 'Ardhapathaka(1)'...
#   Copying 'Katrimukha(1)'...
#   Copying 'Mayura(1)'...
#   Copying 'Ardhachandran(1)'...
#   Copying 'Aralam(1)'...
#   Copying 'Shukatundam(1)'...
#   Copying 'Mushti(1)'...
#   Copying 'Sikharam(1)'...
#   Copying 'Kapith(1)'...
#   Copying 'Katakamukha_1'...
#   Copying 'Katakamukha_2'...
#   Copying 'Katakamukha_3'...
#   Copying 'Suchi(1)'...
#   Copying 'Chandrakala(1)'...
#   Copying 'Padmakosha(1)'...
#   Copying 'Sarpasirsha(1)'...
#   Copying 'Mrigasirsha(1)'...
#   Copying 'Simhamukham(1)'...
#   Copying 'Kangulam(1)'...
#   Copying 'Alapadmam(1)'...
#   Copying 'Chaturam(1)'...
#   Copying 'Bramaram(1)'...
#   Copying 'Hamsasyam(1)'...
#   Copying 'Hamsapaksha(1)'...
#   Copying 'Mukulam(1)'...
#   Copying 'Tamarachudam(1)'...
#   Copying 'Trishulam(1)'...
#
# --- Process Complete ---
# Successfully copied 29 class folders.
# Your new, focused dataset is ready in the 'dataset_foundational_29' folder.
